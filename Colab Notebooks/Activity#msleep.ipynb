# %% [markdown]
# # Read CSV file from github

# %%
import pandas as pd

# %%
df_msleep = pd.read_csv('https://raw.githubusercontent.com/prasertcbs/tutorial/master/msleep.csv')

# %% [markdown]
# # Display the first 8 row

# %%
df_msleep.head(8)
# Out:
#                          name        genus   vore         order  conservation  \
# 0                     Cheetah     Acinonyx  carni     Carnivora            lc
# 1                  Owl monkey        Aotus   omni      Primates           NaN
# 2             Mountain beaver   Aplodontia  herbi      Rodentia            nt
# 3  Greater short-tailed shrew      Blarina   omni  Soricomorpha            lc
# 4                         Cow          Bos  herbi  Artiodactyla  domesticated
# 5            Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 6           Northern fur seal  Callorhinus  carni     Carnivora            vu
# 7                Vesper mouse      Calomys    NaN      Rodentia           NaN
#
#    sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 0         12.1        NaN          NaN   11.9      NaN   50.000
# 1         17.0        1.8          NaN    7.0  0.01550    0.480
# 2         14.4        2.4          NaN    9.6      NaN    1.350
# ...

# %% [markdown]
# # Display column names

# %%
df_msleep.columns.values.tolist()
# Out:
# ['name',
#  'genus',
#  'vore',
#  'order',
#  'conservation',
#  'sleep_total',
#  'sleep_rem',
#  'sleep_cycle',
#  'awake',
#  'brainwt',
#  'bodywt']

# %% [markdown]
# # Display columns for ‘name’, ‘genus’, and ‘sleep_total’

# %%
df_msleep[['name', 'genus', 'sleep_total']]
# Out:
#                           name       genus  sleep_total
# 0                      Cheetah    Acinonyx         12.1
# 1                   Owl monkey       Aotus         17.0
# 2              Mountain beaver  Aplodontia         14.4
# 3   Greater short-tailed shrew     Blarina         14.9
# 4                          Cow         Bos          4.0
# ..                         ...         ...          ...
# 78                  Tree shrew      Tupaia          8.9
# 79        Bottle-nosed dolphin    Tursiops          5.2
# 80                       Genet     Genetta          6.3
# 81                  Arctic fox      Vulpes         12.5
# 82                     Red fox      Vulpes          9.8
#
# [83 rows x 3 columns]

# %% [markdown]
# # What is the type of each attribute? (Nominal, Ordinal, Intervalscaled or Ratio-scaled)

# %% [markdown]
# 1. name - Nominal
# 2. genus - Ordinal
# 3. vore - Nominal
# 4. order - Nominal
# 5. conservation - Nominal
# 6. sleep_total - Interval-scaled
# 7. sleep_rem - Interval-scaled
# 8. sleep_cycle - Interval-scaled
# 9. awake - Interval-scaled
# 10. brainwt - Ratio-scaled
# 11. bodywt - Interval-scaled

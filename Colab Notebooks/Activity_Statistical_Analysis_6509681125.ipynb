# %% [markdown]
# # Load iris dataset

# %%
import pandas as pd
import numpy as np
# import pandas and numpy

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X = iris.data.features
y = iris.data.targets

# metadata
print(iris.metadata)

# variable information
print(iris.variables)
# Out:
# {'uci_id': 53, 'name': 'Iris', 'repository_url': 'https://archive.ics.uci.edu/dataset/53/iris', 'data_url': 'https://archive.ics.uci.edu/static/public/53/data.csv', 'abstract': 'A small classic dataset from Fisher, 1936. One of the earliest known datasets used for evaluating classification methods.\n', 'area': 'Life Science', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 150, 'num_features': 4, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1936, 'last_updated': 'Tue Sep 12 2023', 'dataset_doi': '10.24432/C56C76', 'creators': ['R. A. Fisher'], 'intro_paper': {'title': 'The Iris data set: In search of the source of virginica', 'authors': 'A. Unwin, K. Kleinman', 'published_in': 'Significance, 2021', 'year': 2021, 'url': 'https://www.semanticscholar.org/paper/4599862ea877863669a6a8e63a3c707a787d5d7e', 'doi': '1740-9713.01589'
# ...

# %%
iris_dataset = pd.read_csv("https://archive.ics.uci.edu/static/public/53/data.csv")
# import iris dataset

# %%
iris_dataset
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Calculate statistical values for all variables

# %%
import statistics

# %%
print("Mean of sepal length = ", statistics.mean(iris_dataset["sepal length"]))
print("Mean of sepal width = ", statistics.mean(iris_dataset["sepal width"]))
print("Mean of petal length = ", statistics.mean(iris_dataset["petal length"]))
print("Mean of petal width = ", statistics.mean(iris_dataset["petal width"]))
#Mean
# Out:
# Mean of sepal length =  5.843333333333334
# Mean of sepal width =  3.054
# Mean of petal length =  3.7586666666666666
# Mean of petal width =  1.1986666666666668

# %%
print("Median of sepal length = ", statistics.median(iris_dataset["sepal length"]))
print("Median of sepal width = ", statistics.median(iris_dataset["sepal width"]))
print("Median of petal length = ", statistics.median(iris_dataset["petal length"]))
print("Median of petal width = ", statistics.median(iris_dataset["petal width"]))
#Median
# Out:
# Median of sepal length =  5.8
# Median of sepal width =  3.0
# Median of petal length =  4.35
# Median of petal width =  1.3

# %%
print("Mode of sepal length = ", statistics.mode(iris_dataset["sepal length"]))
print("Mode of sepal width = ", statistics.mode(iris_dataset["sepal width"]))
print("Mode of petal length = ", statistics.mode(iris_dataset["petal length"]))
print("Mode of petal width = ", statistics.mode(iris_dataset["petal width"]))
# Mode
# Out:
# Mode of sepal length =  5.0
# Mode of sepal width =  3.0
# Mode of petal length =  1.5
# Mode of petal width =  0.2

# %%
print("Standard derivation of sepal length = ", statistics.stdev(iris_dataset["sepal length"]))
print("Standard derivation of sepal width = ", statistics.stdev(iris_dataset["sepal width"]))
print("Standard derivation of petal length = ", statistics.stdev(iris_dataset["petal length"]))
print("Standard derivation of petal width = ", statistics.stdev(iris_dataset["petal width"]))
# Standard derivation
# Out:
# Standard derivation of sepal length =  0.8280661279778629
# Standard derivation of sepal width =  0.43359431136217363
# Standard derivation of petal length =  1.7644204199522626
# Standard derivation of petal width =  0.7631607417008411

# %%
print("Skewness of sepal length = ", iris_dataset["sepal length"].skew())
print("Skewness of sepal width = ", iris_dataset["sepal width"].skew())
print("Skewness of petal length = ", iris_dataset["petal length"].skew())
print("Skewness of petal width = ", iris_dataset["petal width"].skew())
# Skewness
# Out:
# Skewness of sepal length =  0.3149109566369728
# Skewness of sepal width =  0.3340526621720866
# Skewness of petal length =  -0.27446425247378287
# Skewness of petal width =  -0.10499656214412734

# %%
print("Kurtosis of sepal length = ", iris_dataset["sepal length"].kurt())
print("Kurtosis of sepal width = ", iris_dataset["sepal width"].kurt())
print("Kurtosis of petal length = ", iris_dataset["petal length"].kurt())
print("Kurtosis of petal width = ", iris_dataset["petal width"].kurt())
# Kurtosis
# Out:
# Kurtosis of sepal length =  -0.5520640413156395
# Kurtosis of sepal width =  0.2907810623654279
# Kurtosis of petal length =  -1.4019208006454036
# Kurtosis of petal width =  -1.3397541711393433

# %% [markdown]
# # Calculate covariance and correlation values between petal length and petal width

# %%
df = iris_dataset[["petal length", "petal width"]]
df.cov()
# Covariance
# Out:
#               petal length  petal width
# petal length      3.113179     1.296387
# petal width       1.296387     0.582414

# %%
df2 = iris_dataset[["petal length", "petal width"]]
df2.corr()
# Correlation
# Out:
#               petal length  petal width
# petal length      1.000000     0.962757
# petal width       0.962757     1.000000

# %% [markdown]
# # What do the covariance and correlation tell about the relation between petal length and petal width

# %% [markdown]
# Covariance shows if petal length and width change together (positive or negative), while correlation measures how strongly they do so (closer to -1 or +1 means stronger relationship).
